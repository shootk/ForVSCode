# %%
import numpy as mp
from sklearn.naive_bayes import GaussianNB
# %run utilities.ipynb

# %%
input_file = 'data_multivar_nb.txt'

# %%
data = np.loadtxt(input_file,delimiter=',')
X,y = data[:, :-1], data[:, -1]
classifier = GaussianNB()
classifier.fit(X,y)
y_pred = classifier.predict(X)

accuracy = 100.0 * (y == y_pred).sum() / X.shape[0]
print("Accuracy of Naive Bayes classifier = ",round(accuracy,2),"%")

visualize_classifier(classifier,X,y)
# Out:
# Accuracy of Naive Bayes classifier =  99.75 %
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-68b4f6474dcd> in <module>
#       8 print("Accuracy of Naive Bayes classifier = ",round(accuracy,2),"%")
#       9
# ---> 10 visualize_classifier(classifier,X,y)
#
# <ipython-input-16-f497d407a000> in visualize_classifier(classifier, X, y, title)
#      19     plt.ylim(y_vals.min(),y_vals.max())
#      20
# ---> 21     plt.xticks((np.arange(int(min_x)),int(max_x),1.0))
#      22     plt.yticks((np.arange(int(min_y)),int(max_y),1.0))
#      23
#
# c:\users\a151410\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1532         labels = ax.get_xticklabels()
#    1533     elif labels is None:
# -> 1534         locs = ax.set_xticks(ticks)
#    1535         labels = ax.get_xticklabels()
#    1536     else:
#
# c:\users\a151410\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3343             Default is ``False``.
#    3344         """
# -> 3345         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3346         self.stale = True
#    3347         return ret
#
# c:\users\a151410\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1754             xleft, xright = self.get_view_interval()
#    1755             if xright > xleft:
# -> 1756                 self.set_view_interval(min(ticks), max(ticks))
#    1757             else:
#    1758                 self.set_view_interval(max(ticks), min(ticks))
#
# c:\users\a151410\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in set_view_interval(self, vmin, vmax, ignore)
#    2131             if Vmin < Vmax:
#    2132                 self.axes.viewLim.intervalx = (min(vmin, vmax, Vmin),
# -> 2133                                                max(vmin, vmax, Vmax))
#    2134             else:
#    2135                 self.axes.viewLim.intervalx = (max(vmin, vmax, Vmin),
#
# c:\users\a151410\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in intervalx(self, interval)
#     916     @BboxBase.intervalx.setter
#     917     def intervalx(self, interval):
# --> 918         self._points[:, 0] = interval
#     919         self.invalidate()
#     920
#
# ValueError: setting an array element with a sequence.
